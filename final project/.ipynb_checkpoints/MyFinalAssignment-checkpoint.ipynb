# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns
import matplotlib.pyplot as plt
from math import sqrt
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler

# Label Encoding
from sklearn.preprocessing import LabelEncoder
# Modeling & Accuracy Metrics
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
# import xgboost as xgb
from sklearn.datasets import load_boston
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#reading data
data=pd.read_csv("Training Data.csv")

# %%
#checking for null value in column
data.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                 3899
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             50000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    7
# isOpen                        0
# dtype: int64

# %%
#Where clear_date != null is putted into train dataframe
train = data.loc[data['clear_date'].notnull()]
train.shape
# Out:
# (46101, 19)

# %%
#Where clear_date == null is putted into test dataframe
test = data.loc[data.clear_date.isnull()]
test.shape
# Out:
# (3899, 19)

# %%
#taken for recall train dataframe
temp_test_data = data.loc[data.clear_date.isnull()]
temp_test_data.shape
# Out:
# (3899, 19)

# %%
#checking for null values inside train
train.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                    0
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             46101
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    7
# isOpen                        0
# dtype: int64

# %%
#area_business column is full of null value and invoice_id has no requarement for training . so droped
train.drop(columns=['area_business','invoice_id'],inplace=True)
train.isnull().sum()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# business_code             0
# cust_number               0
# name_customer             0
# clear_date                0
# buisness_year             0
# doc_id                    0
# posting_date              0
# document_create_date      0
# document_create_date.1    0
# due_in_date               0
# invoice_currency          0
# document type             0
# posting_id                0
# total_open_amount         0
# baseline_create_date      0
# cust_payment_terms        0
# isOpen                    0
# dtype: int64

# %%
#sort the train data according to document_create_date.1
train.sort_values(['document_create_date.1'],inplace=True)
train.reset_index(inplace=True,drop=True)
train.head()
# Out:
# <ipython-input-9-c5b1ec83635a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.sort_values(['document_create_date.1'],inplace=True)
#   business_code cust_number      name_customer           clear_date  \
# 0          CA02  0140106408           WAL-M us  2019-01-25 00:00:00
# 1          U001  0200769623      WAL-MAR trust  2019-01-10 00:00:00
# 2          U001  0200726979  BJ'S  corporation  2019-01-15 00:00:00
# 3          U001  0200762301          C&S WH in  2019-01-15 00:00:00
# 4          U001  0200769623         WAL-MAR in  2019-01-10 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2019.0  2.960520e+09   2018-12-30              20181230
# 1         2019.0  1.928543e+09   2018-12-30              20181230
# 2         2019.0  1.928542e+09   2018-12-30              20181229
# 3         2019.0  1.928543e+09   2018-12-30              20181230
# 4         2019.0  1.928543e+09   2018-12-30              20181230
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20181230   20190109.0              CAD            RV
# 1                20181230   20190114.0              USD            RV
# 2                20181230   20190114.0              USD            RV
# 3                20181230   20190114.0              USD            RV
# 4                20181230   20190114.0              USD            RV
#
#    posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 0         1.0            4977.45            20181230.0               CA10
# 1         1.0           12428.72            20181230.0               NAH4
# 2         1.0              89.75            20181230.0               NAA8
# 3         1.0           26125.08            20181230.0               NAC6
# 4         1.0            1764.66            20181230.0               NAH4
#
#    isOpen
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#80% of train data will used for train_final and 20% is for validation pourpose
train_final, validation_intermediate = train_test_split(train,test_size=.2,shuffle=False)
train_final.shape,validation_intermediate.shape
# Out:
# ((36880, 17), (9221, 17))

# %%
#20% validation data is splited 50% slab (in the sorted document_create_date.1)
validation_final,test_final = train_test_split(validation_intermediate,test_size=.5,shuffle=False)
validation_final.shape,test_final.shape
# Out:
# ((4610, 17), (4611, 17))

# %% [markdown]
# ####  Training for train_final

# %%
[col for col in train_final.columns if train_final[col].isnull().sum() > 0]
# Out:
# []

# %%
train_final.head()
# Out:
#   business_code cust_number      name_customer           clear_date  \
# 0          CA02  0140106408           WAL-M us  2019-01-25 00:00:00
# 1          U001  0200769623      WAL-MAR trust  2019-01-10 00:00:00
# 2          U001  0200726979  BJ'S  corporation  2019-01-15 00:00:00
# 3          U001  0200762301          C&S WH in  2019-01-15 00:00:00
# 4          U001  0200769623         WAL-MAR in  2019-01-10 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2019.0  2.960520e+09   2018-12-30              20181230
# 1         2019.0  1.928543e+09   2018-12-30              20181230
# 2         2019.0  1.928542e+09   2018-12-30              20181229
# 3         2019.0  1.928543e+09   2018-12-30              20181230
# 4         2019.0  1.928543e+09   2018-12-30              20181230
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20181230   20190109.0              CAD            RV
# 1                20181230   20190114.0              USD            RV
# 2                20181230   20190114.0              USD            RV
# 3                20181230   20190114.0              USD            RV
# 4                20181230   20190114.0              USD            RV
#
#    posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 0         1.0            4977.45            20181230.0               CA10
# 1         1.0           12428.72            20181230.0               NAH4
# 2         1.0              89.75            20181230.0               NAA8
# 3         1.0           26125.08            20181230.0               NAC6
# 4         1.0            1764.66            20181230.0               NAH4
#
#    isOpen
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# temp_constant_check is taken for constant checking pourpose
temp_constant_check = train_final.drop(labels=['cust_number','business_code','name_customer','clear_date','posting_date','invoice_currency','document type','cust_payment_terms'], axis=1)
temp_constant_check.dtypes
# Out:
# buisness_year             float64
# doc_id                    float64
# document_create_date        int64
# document_create_date.1      int64
# due_in_date               float64
# posting_id                float64
# total_open_amount         float64
# baseline_create_date      float64
# isOpen                      int64
# dtype: object

# %%
temp_constant_check.head()
# Out:
#    buisness_year        doc_id  document_create_date  document_create_date.1  \
# 0         2019.0  2.960520e+09              20181230                20181230
# 1         2019.0  1.928543e+09              20181230                20181230
# 2         2019.0  1.928542e+09              20181229                20181230
# 3         2019.0  1.928543e+09              20181230                20181230
# 4         2019.0  1.928543e+09              20181230                20181230
#
#    due_in_date  posting_id  total_open_amount  baseline_create_date  isOpen
# 0   20190109.0         1.0            4977.45            20181230.0       0
# 1   20190114.0         1.0           12428.72            20181230.0       0
# 2   20190114.0         1.0              89.75            20181230.0       0
# 3   20190114.0         1.0           26125.08            20181230.0       0
# 4   20190114.0         1.0            1764.66            20181230.0       0

# %%
#checking for quasi-constant 
sel = VarianceThreshold(
    threshold=0.01)

sel.fit(temp_constant_check)
sum(sel.get_support())
# Out:
# 6

# %%
len(temp_constant_check.columns[sel.get_support()])
# Out:
# 6

# %%
# finally we can print the quasi-constant features
print(
    len([
        x for x in temp_constant_check.columns
        if x not in temp_constant_check.columns[sel.get_support()]
    ]))

[x for x in temp_constant_check.columns if x not in temp_constant_check.columns[sel.get_support()]]
# Out:
# 3
# ['buisness_year', 'posting_id', 'isOpen']

# %%
#quasi-constant are removed
train_final.drop(columns=['buisness_year','posting_id','isOpen'],inplace=True)
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# corelation is performed to detect corelated colum
corelation = train_final.corr()
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
#removed corelated colum
train_final.drop(columns=['document_create_date','baseline_create_date'],inplace=True)

# %%
#clear_date,posting_date,document_create_date.1,due_in_date are converted into datetime format for future operation
train_final['clear_date'] = pd.to_datetime(train_final['clear_date'])
train_final['posting_date'] = pd.to_datetime(train_final['posting_date']) 
train_final['document_create_date.1'] = pd.to_datetime(train_final['document_create_date.1'], format='%Y%m%d')
train_final['due_in_date'] = pd.to_datetime(train_final['due_in_date'], format='%Y%m%d')
train_final.head()
# Out:
# <ipython-input-22-5260b159a482>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['clear_date'] = pd.to_datetime(train_final['clear_date'])
# <ipython-input-22-5260b159a482>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['posting_date'] = pd.to_datetime(train_final['posting_date'])
# <ipython-input-22-5260b159a482>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['document_create_date.1'] = pd.to_datetime(train_final['document_create_date.1'], format='%Y%m%d')
# <ipython-input-22-5260b159a482>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['due_in_date'] = pd.to_datetime(train_final['due_in_date'], format='%Y%m%d')
#   business_code cust_number      name_customer clear_date        doc_id  \
# 0          CA02  0140106408           WAL-M us 2019-01-25  2.960520e+09
# 1          U001  0200769623      WAL-MAR trust 2019-01-10  1.928543e+09
# 2          U001  0200726979  BJ'S  corporation 2019-01-15  1.928542e+09
# 3          U001  0200762301          C&S WH in 2019-01-15  1.928543e+09
# 4          U001  0200769623         WAL-MAR in 2019-01-10  1.928543e+09
#
#   posting_date document_create_date.1 due_in_date invoice_currency  \
# 0   2018-12-30             2018-12-30  2019-01-09              CAD
# 1   2018-12-30             2018-12-30  2019-01-14              USD
# 2   2018-12-30             2018-12-30  2019-01-14              USD
# 3   2018-12-30             2018-12-30  2019-01-14              USD
# 4   2018-12-30             2018-12-30  2019-01-14              USD
#
#   document type  total_open_amount cust_payment_terms
# 0            RV            4977.45               CA10
# 1            RV           12428.72               NAH4
# 2            RV              89.75               NAA8
# 3            RV           26125.08               NAC6
# 4            RV            1764.66               NAH4

# %%
# posting_date,document_create_date.1 are making straightline graph so they are almost similar fetcher
plt.plot_date(train_final['posting_date'], train_final['document_create_date.1'])
plt.show()

# %%
#posting_date are removed for similarity with of document_create_date.1
train_final.drop(columns=['posting_date'],inplace=True)
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#DELAY is calculated by (clear_date-due_in_date)
train_final['DELAY']=train_final['clear_date'] - train_final['due_in_date']
train_final.head()
# Out:
# <ipython-input-25-d0bf8ccd5776>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['DELAY']=train_final['clear_date'] - train_final['due_in_date']
#   business_code cust_number      name_customer clear_date        doc_id  \
# 0          CA02  0140106408           WAL-M us 2019-01-25  2.960520e+09
# 1          U001  0200769623      WAL-MAR trust 2019-01-10  1.928543e+09
# 2          U001  0200726979  BJ'S  corporation 2019-01-15  1.928542e+09
# 3          U001  0200762301          C&S WH in 2019-01-15  1.928543e+09
# 4          U001  0200769623         WAL-MAR in 2019-01-10  1.928543e+09
#
#   document_create_date.1 due_in_date invoice_currency document type  \
# 0             2018-12-30  2019-01-09              CAD            RV
# 1             2018-12-30  2019-01-14              USD            RV
# 2             2018-12-30  2019-01-14              USD            RV
# 3             2018-12-30  2019-01-14              USD            RV
# 4             2018-12-30  2019-01-14              USD            RV
#
#    total_open_amount cust_payment_terms   DELAY
# 0            4977.45               CA10 16 days
# 1           12428.72               NAH4 -4 days
# 2              89.75               NAA8  1 days
# 3           26125.08               NAC6  1 days
# 4            1764.66               NAH4 -4 days

# %%
train_final.shape
# Out:
# (36880, 12)

# %%
train_final[train_final['invoice_currency'] == 'CAD']
# Out:
#       business_code cust_number       name_customer clear_date        doc_id  \
# 0              CA02  0140106408            WAL-M us 2019-01-25  2.960520e+09
# 39             CA02  0140105847    GORDON F systems 2019-01-14  2.960521e+09
# 48             CA02  0140104229  A & W F associates 2019-01-18  2.960521e+09
# 108            CA02  0140104440                 SO  2019-01-16  2.960521e+09
# 129            CA02  0140104423        METRO  trust 2019-01-15  2.960520e+09
# ...             ...         ...                 ...        ...           ...
# 36835          CA02  0140106249        FINDLAY corp 2019-11-27  2.960594e+09
# 36842          CA02  0140104429           COSTCO co 2019-11-25  2.960594e+09
# 36853          CA02  0140105785  SHOPPE corporation 2019-12-09  2.960593e+09
# 36861          CA02  0140104285            BUY- llc 2019-12-09  2.960594e+09
# 36862          CA02      CCU001        KRAFT  trust 2019-12-20  2.960594e+09
#
#       document_create_date.1 due_in_date invoice_currency document type  \
# 0                 2018-12-30  2019-01-09              CAD            RV
# 39                2018-12-30  2019-01-12              CAD            RV
# 48                2018-12-30  2019-01-10              CAD            RV
# 108               2018-12-31  2019-01-12              CAD            RV
# 129               2018-12-31  2019-01-13              CAD            RV
# ...                      ...         ...              ...           ...
# 36835             2019-11-18  2019-11-30              CAD            RV
# 36842             2019-11-18  2019-11-30              CAD            RV
# 36853             2019-11-18  2019-12-06              CAD            RV
# 36861             2019-11-18  2019-12-06              CAD            RV
# 36862             2019-11-18  2019-12-24              CAD            RV
#
#        total_open_amount cust_payment_terms   DELAY
# 0                4977.45               CA10 16 days
# 39              66459.30               CA10  2 days
# 48               4612.95               CA10  8 days
# 108             89597.99               CA10  4 days
# 129             49685.50               CA10  2 days
# ...                  ...                ...     ...
# 36835           10817.89               CA10 -3 days
# 36842            8567.96               CA10 -5 days
# 36853           15099.53               CA10  3 days
# 36861            2411.94               CA10  3 days
# 36862           23572.90               NAG2 -4 days
#
# [2971 rows x 12 columns]

# %%
train_final.dtypes
# Out:
# business_code                      object
# cust_number                        object
# name_customer                      object
# clear_date                 datetime64[ns]
# doc_id                            float64
# document_create_date.1     datetime64[ns]
# due_in_date                datetime64[ns]
# invoice_currency                   object
# document type                      object
# total_open_amount                 float64
# cust_payment_terms                 object
# DELAY                     timedelta64[ns]
# dtype: object

# %%
#CAD are converted into USD
train_final['total_open_amount'] = np.where((train_final['invoice_currency'] == 'CAD') ,((train_final['total_open_amount'])*0.78),(train_final['total_open_amount']))
# Out:
# <ipython-input-29-ce9a23ebc547>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['total_open_amount'] = np.where((train_final['invoice_currency'] == 'CAD') ,((train_final['total_open_amount'])*0.78),(train_final['total_open_amount']))

# %%
train_final.head()
# Out:
#   business_code cust_number      name_customer clear_date        doc_id  \
# 0          CA02  0140106408           WAL-M us 2019-01-25  2.960520e+09
# 1          U001  0200769623      WAL-MAR trust 2019-01-10  1.928543e+09
# 2          U001  0200726979  BJ'S  corporation 2019-01-15  1.928542e+09
# 3          U001  0200762301          C&S WH in 2019-01-15  1.928543e+09
# 4          U001  0200769623         WAL-MAR in 2019-01-10  1.928543e+09
#
#   document_create_date.1 due_in_date invoice_currency document type  \
# 0             2018-12-30  2019-01-09              CAD            RV
# 1             2018-12-30  2019-01-14              USD            RV
# 2             2018-12-30  2019-01-14              USD            RV
# 3             2018-12-30  2019-01-14              USD            RV
# 4             2018-12-30  2019-01-14              USD            RV
#
#    total_open_amount cust_payment_terms   DELAY
# 0           3882.411               CA10 16 days
# 1          12428.720               NAH4 -4 days
# 2             89.750               NAA8  1 days
# 3          26125.080               NAC6  1 days
# 4           1764.660               NAH4 -4 days

# %%
train_final['invoice_currency'] = 'USD'
train_final.head()
# Out:
# <ipython-input-31-0ec984ec0d39>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['invoice_currency'] = 'USD'
#   business_code cust_number      name_customer clear_date        doc_id  \
# 0          CA02  0140106408           WAL-M us 2019-01-25  2.960520e+09
# 1          U001  0200769623      WAL-MAR trust 2019-01-10  1.928543e+09
# 2          U001  0200726979  BJ'S  corporation 2019-01-15  1.928542e+09
# 3          U001  0200762301          C&S WH in 2019-01-15  1.928543e+09
# 4          U001  0200769623         WAL-MAR in 2019-01-10  1.928543e+09
#
#   document_create_date.1 due_in_date invoice_currency document type  \
# 0             2018-12-30  2019-01-09              USD            RV
# 1             2018-12-30  2019-01-14              USD            RV
# 2             2018-12-30  2019-01-14              USD            RV
# 3             2018-12-30  2019-01-14              USD            RV
# 4             2018-12-30  2019-01-14              USD            RV
#
#    total_open_amount cust_payment_terms   DELAY
# 0           3882.411               CA10 16 days
# 1          12428.720               NAH4 -4 days
# 2             89.750               NAA8  1 days
# 3          26125.080               NAC6  1 days
# 4           1764.660               NAH4 -4 days

# %%
# doc_id, document type and name_customer are removed because they have no roll in training
train_final.drop(columns=['doc_id','document type','name_customer'],inplace=True)
train_final.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#   business_code cust_number clear_date document_create_date.1 due_in_date  \
# 0          CA02  0140106408 2019-01-25             2018-12-30  2019-01-09
# 1          U001  0200769623 2019-01-10             2018-12-30  2019-01-14
# 2          U001  0200726979 2019-01-15             2018-12-30  2019-01-14
# 3          U001  0200762301 2019-01-15             2018-12-30  2019-01-14
# 4          U001  0200769623 2019-01-10             2018-12-30  2019-01-14
#
#   invoice_currency  total_open_amount cust_payment_terms   DELAY
# 0              USD           3882.411               CA10 16 days
# 1              USD          12428.720               NAH4 -4 days
# 2              USD             89.750               NAA8  1 days
# 3              USD          26125.080               NAC6  1 days
# 4              USD           1764.660               NAH4 -4 days

# %%
# month_quarter,month are calculated for further use
train_final['document_create_date.1_month_quarter'] = train_final['document_create_date.1'].dt.quarter
train_final['due_in_date_month_quarter'] = train_final['due_in_date'].dt.quarter
train_final['document_create_date.1_month'] = train_final['document_create_date.1'].dt.month
train_final['due_in_date_month'] = train_final['due_in_date'].dt.month

train_final.head()
# Out:
# <ipython-input-33-8d76bd0d7c0c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['document_create_date.1_month_quarter'] = train_final['document_create_date.1'].dt.quarter
# <ipython-input-33-8d76bd0d7c0c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['due_in_date_month_quarter'] = train_final['due_in_date'].dt.quarter
# <ipython-input-33-8d76bd0d7c0c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['document_create_date.1_month'] = train_final['document_create_date.1'].dt.month
# <ipython-input-33-8d76bd0d7c0c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['due_in_date_month'] = train_final['due_in_date'].dt.month
#   business_code cust_number clear_date document_create_date.1 due_in_date  \
# 0          CA02  0140106408 2019-01-25             2018-12-30  2019-01-09
# 1          U001  0200769623 2019-01-10             2018-12-30  2019-01-14
# 2          U001  0200726979 2019-01-15             2018-12-30  2019-01-14
# 3          U001  0200762301 2019-01-15             2018-12-30  2019-01-14
# 4          U001  0200769623 2019-01-10             2018-12-30  2019-01-14
#
#   invoice_currency  total_open_amount cust_payment_terms   DELAY  \
# 0              USD           3882.411               CA10 16 days
# 1              USD          12428.720               NAH4 -4 days
# 2              USD             89.750               NAA8  1 days
# 3              USD          26125.080               NAC6  1 days
# 4              USD           1764.660               NAH4 -4 days
#
#    document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 0                                     4                          1
# 1                                     4                          1
# 2                                     4                          1
# 3                                     4                          1
# 4                                     4                          1
#
#    document_create_date.1_month  due_in_date_month
# 0                            12                  1
# 1                            12                  1
# 2                            12                  1
# 3                            12                  1
# 4                            12                  1

# %%
train_final.head()
# Out:
#   business_code cust_number clear_date document_create_date.1 due_in_date  \
# 0          CA02  0140106408 2019-01-25             2018-12-30  2019-01-09
# 1          U001  0200769623 2019-01-10             2018-12-30  2019-01-14
# 2          U001  0200726979 2019-01-15             2018-12-30  2019-01-14
# 3          U001  0200762301 2019-01-15             2018-12-30  2019-01-14
# 4          U001  0200769623 2019-01-10             2018-12-30  2019-01-14
#
#   invoice_currency  total_open_amount cust_payment_terms   DELAY  \
# 0              USD           3882.411               CA10 16 days
# 1              USD          12428.720               NAH4 -4 days
# 2              USD             89.750               NAA8  1 days
# 3              USD          26125.080               NAC6  1 days
# 4              USD           1764.660               NAH4 -4 days
#
#    document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 0                                     4                          1
# 1                                     4                          1
# 2                                     4                          1
# 3                                     4                          1
# 4                                     4                          1
#
#    document_create_date.1_month  due_in_date_month
# 0                            12                  1
# 1                            12                  1
# 2                            12                  1
# 3                            12                  1
# 4                            12                  1

# %%
train_final.shape
# Out:
# (36880, 13)

# %%
# lablencoding is performed in business_code,cust_number and cust_payment_terms because they are catagorical column and can not passed into model
labelencoder = LabelEncoder()
train_final.iloc[:,0] = labelencoder.fit_transform(train_final.iloc[:,0])
train_final.iloc[:,1] = labelencoder.fit_transform(train_final.iloc[:,1])
train_final.iloc[:,7] = labelencoder.fit_transform(train_final.iloc[:,7])
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
train_final.head()
# Out:
#    business_code  cust_number clear_date document_create_date.1 due_in_date  \
# 0              0          419 2019-01-25             2018-12-30  2019-01-09
# 1              1          831 2019-01-10             2018-12-30  2019-01-14
# 2              1          727 2019-01-15             2018-12-30  2019-01-14
# 3              1          815 2019-01-15             2018-12-30  2019-01-14
# 4              1          831 2019-01-10             2018-12-30  2019-01-14
#
#   invoice_currency  total_open_amount  cust_payment_terms   DELAY  \
# 0              USD           3882.411                   6 16 days
# 1              USD          12428.720                  35 -4 days
# 2              USD             89.750                  22  1 days
# 3              USD          26125.080                  27  1 days
# 4              USD           1764.660                  35 -4 days
#
#    document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 0                                     4                          1
# 1                                     4                          1
# 2                                     4                          1
# 3                                     4                          1
# 4                                     4                          1
#
#    document_create_date.1_month  due_in_date_month
# 0                            12                  1
# 1                            12                  1
# 2                            12                  1
# 3                            12                  1
# 4                            12                  1

# %%
train_final['invoice_currency'].unique()
# Out:
# array(['USD'], dtype=object)

# %%
#As CAD was converted into USD so invoice_currency has no use so dropped
train_final.drop(columns=['invoice_currency'],inplace=True)
train_final.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#    business_code  cust_number clear_date document_create_date.1 due_in_date  \
# 0              0          419 2019-01-25             2018-12-30  2019-01-09
# 1              1          831 2019-01-10             2018-12-30  2019-01-14
# 2              1          727 2019-01-15             2018-12-30  2019-01-14
# 3              1          815 2019-01-15             2018-12-30  2019-01-14
# 4              1          831 2019-01-10             2018-12-30  2019-01-14
#
#    total_open_amount  cust_payment_terms   DELAY  \
# 0           3882.411                   6 16 days
# 1          12428.720                  35 -4 days
# 2             89.750                  22  1 days
# 3          26125.080                  27  1 days
# 4           1764.660                  35 -4 days
#
#    document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 0                                     4                          1
# 1                                     4                          1
# 2                                     4                          1
# 3                                     4                          1
# 4                                     4                          1
#
#    document_create_date.1_month  due_in_date_month
# 0                            12                  1
# 1                            12                  1
# 2                            12                  1
# 3                            12                  1
# 4                            12                  1

# %%
#clear_date,document_create_date.1,due_in_date are dropped because they are catagorical column and can not be passed into model
train_final.drop(columns=['clear_date','document_create_date.1','due_in_date'],inplace=True)
train_final['DELAY'] = train_final['DELAY'].dt.days
train_final.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-40-1a49c618d5df>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_final['DELAY'] = train_final['DELAY'].dt.days
#    business_code  cust_number  total_open_amount  cust_payment_terms  DELAY  \
# 0              0          419           3882.411                   6     16
# 1              1          831          12428.720                  35     -4
# 2              1          727             89.750                  22      1
# 3              1          815          26125.080                  27      1
# 4              1          831           1764.660                  35     -4
#
#    document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 0                                     4                          1
# 1                                     4                          1
# 2                                     4                          1
# 3                                     4                          1
# 4                                     4                          1
#
#    document_create_date.1_month  due_in_date_month
# 0                            12                  1
# 1                            12                  1
# 2                            12                  1
# 3                            12                  1
# 4                            12                  1

# %%
train_final.describe()
# Out:
#        business_code   cust_number  total_open_amount  cust_payment_terms  \
# count   36880.000000  36880.000000       36880.000000        36880.000000
# mean        0.979176    769.722234       30877.945613           27.739723
# std         0.553835    255.920508       37367.987814           11.784629
# min         0.000000      0.000000           0.780000            0.000000
# 25%         1.000000    682.000000        4427.070000           22.000000
# 50%         1.000000    831.000000       16928.395000           22.000000
# 75%         1.000000    846.000000       45381.832500           35.000000
# max         5.000000   1345.000000      985247.060000           67.000000
#
#               DELAY  document_create_date.1_month_quarter  \
# count  36880.000000                          36880.000000
# mean       1.014018                              2.322668
# std       11.290258                              1.036107
# min      -83.000000                              1.000000
# 25%       -3.000000                              1.000000
# 50%        0.000000                              2.000000
# 75%        2.000000                              3.000000
# max      212.000000                              4.000000
#
#        due_in_date_month_quarter  document_create_date.1_month  \
# count               36880.000000                  36880.000000
# mean                    2.478091                      5.886876
# std                     1.046368                      3.044105
# min                     1.000000                      1.000000
# 25%                     2.000000                      3.000000
# 50%                     2.000000                      6.000000
# 75%                     3.000000                      8.000000
# max                     4.000000                     12.000000
#
#        due_in_date_month
# count       36880.000000
# mean            6.402223
# std             3.050367
# min             1.000000
# 25%             4.000000
# 50%             6.000000
# 75%             9.000000
# max            12.000000

# %% [markdown]
# #### preparation in validation_final  dataframe for fitting into model

# %%
validation_final.drop(columns=['buisness_year','posting_id','isOpen'],inplace=True)
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
validation_final.drop(columns=['document_create_date','baseline_create_date'],inplace=True)
validation_final.head()
# Out:
#       business_code cust_number   name_customer           clear_date  \
# 36880          U001  0200230690         DECA in  2019-12-02 00:00:00
# 36881          CA02  0140104409  LOB foundation  2019-12-06 00:00:00
# 36882          U001  0200744019         TARG us  2019-12-05 00:00:00
# 36883          U001  0200769623        WAL-MAR   2019-12-02 00:00:00
# 36884          U001  0200705742            DOT   2019-12-04 00:00:00
#
#              doc_id posting_date  document_create_date.1  due_in_date  \
# 36880  1.930165e+09   2019-11-19                20191119   20191209.0
# 36881  2.960594e+09   2019-11-19                20191119   20191208.0
# 36882  1.930169e+09   2019-11-19                20191119   20191204.0
# 36883  1.930169e+09   2019-11-19                20191119   20191204.0
# 36884  1.930169e+09   2019-11-19                20191119   20191204.0
#
#       invoice_currency document type  total_open_amount cust_payment_terms
# 36880              USD            RV             455.64               NAM4
# 36881              CAD            RV           93267.97               CA10
# 36882              USD            RV          102106.93               NAA8
# 36883              USD            RV           20139.74               NAH4
# 36884              USD            RV           16980.61               NAA8

# %%
validation_final['clear_date'] = pd.to_datetime(validation_final['clear_date'])
validation_final['posting_date'] = pd.to_datetime(validation_final['posting_date']) 
validation_final['document_create_date.1'] = pd.to_datetime(validation_final['document_create_date.1'], format='%Y%m%d')
validation_final['due_in_date'] = pd.to_datetime(validation_final['due_in_date'], format='%Y%m%d')
validation_final.head()
# Out:
# <ipython-input-44-e4f45ad51e80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['clear_date'] = pd.to_datetime(validation_final['clear_date'])
# <ipython-input-44-e4f45ad51e80>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['posting_date'] = pd.to_datetime(validation_final['posting_date'])
# <ipython-input-44-e4f45ad51e80>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['document_create_date.1'] = pd.to_datetime(validation_final['document_create_date.1'], format='%Y%m%d')
# <ipython-input-44-e4f45ad51e80>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['due_in_date'] = pd.to_datetime(validation_final['due_in_date'], format='%Y%m%d')
#       business_code cust_number   name_customer clear_date        doc_id  \
# 36880          U001  0200230690         DECA in 2019-12-02  1.930165e+09
# 36881          CA02  0140104409  LOB foundation 2019-12-06  2.960594e+09
# 36882          U001  0200744019         TARG us 2019-12-05  1.930169e+09
# 36883          U001  0200769623        WAL-MAR  2019-12-02  1.930169e+09
# 36884          U001  0200705742            DOT  2019-12-04  1.930169e+09
#
#       posting_date document_create_date.1 due_in_date invoice_currency  \
# 36880   2019-11-19             2019-11-19  2019-12-09              USD
# 36881   2019-11-19             2019-11-19  2019-12-08              CAD
# 36882   2019-11-19             2019-11-19  2019-12-04              USD
# 36883   2019-11-19             2019-11-19  2019-12-04              USD
# 36884   2019-11-19             2019-11-19  2019-12-04              USD
#
#       document type  total_open_amount cust_payment_terms
# 36880            RV             455.64               NAM4
# 36881            RV           93267.97               CA10
# 36882            RV          102106.93               NAA8
# 36883            RV           20139.74               NAH4
# 36884            RV           16980.61               NAA8

# %%
validation_final.drop(columns=['posting_date'],inplace=True)
validation_final.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       business_code cust_number   name_customer clear_date        doc_id  \
# 36880          U001  0200230690         DECA in 2019-12-02  1.930165e+09
# 36881          CA02  0140104409  LOB foundation 2019-12-06  2.960594e+09
# 36882          U001  0200744019         TARG us 2019-12-05  1.930169e+09
# 36883          U001  0200769623        WAL-MAR  2019-12-02  1.930169e+09
# 36884          U001  0200705742            DOT  2019-12-04  1.930169e+09
#
#       document_create_date.1 due_in_date invoice_currency document type  \
# 36880             2019-11-19  2019-12-09              USD            RV
# 36881             2019-11-19  2019-12-08              CAD            RV
# 36882             2019-11-19  2019-12-04              USD            RV
# 36883             2019-11-19  2019-12-04              USD            RV
# 36884             2019-11-19  2019-12-04              USD            RV
#
#        total_open_amount cust_payment_terms
# 36880             455.64               NAM4
# 36881           93267.97               CA10
# 36882          102106.93               NAA8
# 36883           20139.74               NAH4
# 36884           16980.61               NAA8

# %%
validation_final['DELAY']=validation_final['clear_date'] - validation_final['due_in_date']
validation_final.head()
# Out:
# <ipython-input-46-c438f808a076>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['DELAY']=validation_final['clear_date'] - validation_final['due_in_date']
#       business_code cust_number   name_customer clear_date        doc_id  \
# 36880          U001  0200230690         DECA in 2019-12-02  1.930165e+09
# 36881          CA02  0140104409  LOB foundation 2019-12-06  2.960594e+09
# 36882          U001  0200744019         TARG us 2019-12-05  1.930169e+09
# 36883          U001  0200769623        WAL-MAR  2019-12-02  1.930169e+09
# 36884          U001  0200705742            DOT  2019-12-04  1.930169e+09
#
#       document_create_date.1 due_in_date invoice_currency document type  \
# 36880             2019-11-19  2019-12-09              USD            RV
# 36881             2019-11-19  2019-12-08              CAD            RV
# 36882             2019-11-19  2019-12-04              USD            RV
# 36883             2019-11-19  2019-12-04              USD            RV
# 36884             2019-11-19  2019-12-04              USD            RV
#
#        total_open_amount cust_payment_terms   DELAY
# 36880             455.64               NAM4 -7 days
# 36881           93267.97               CA10 -2 days
# 36882          102106.93               NAA8  1 days
# 36883           20139.74               NAH4 -2 days
# 36884           16980.61               NAA8  0 days

# %%
validation_final['total_open_amount'] = np.where((validation_final['invoice_currency'] == 'CAD') ,((validation_final['total_open_amount'])*0.78),(validation_final['total_open_amount']))
validation_final.drop(columns=['invoice_currency'],inplace=True)
validation_final.head()
# Out:
# <ipython-input-47-04d7233e2730>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['total_open_amount'] = np.where((validation_final['invoice_currency'] == 'CAD') ,((validation_final['total_open_amount'])*0.78),(validation_final['total_open_amount']))
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       business_code cust_number   name_customer clear_date        doc_id  \
# 36880          U001  0200230690         DECA in 2019-12-02  1.930165e+09
# 36881          CA02  0140104409  LOB foundation 2019-12-06  2.960594e+09
# 36882          U001  0200744019         TARG us 2019-12-05  1.930169e+09
# 36883          U001  0200769623        WAL-MAR  2019-12-02  1.930169e+09
# 36884          U001  0200705742            DOT  2019-12-04  1.930169e+09
#
#       document_create_date.1 due_in_date document type  total_open_amount  \
# 36880             2019-11-19  2019-12-09            RV           455.6400
# 36881             2019-11-19  2019-12-08            RV         72749.0166
# 36882             2019-11-19  2019-12-04            RV        102106.9300
# 36883             2019-11-19  2019-12-04            RV         20139.7400
# 36884             2019-11-19  2019-12-04            RV         16980.6100
#
#       cust_payment_terms   DELAY
# 36880               NAM4 -7 days
# 36881               CA10 -2 days
# 36882               NAA8  1 days
# 36883               NAH4 -2 days
# 36884               NAA8  0 days

# %%
validation_final.drop(columns=['doc_id','document type','name_customer'],inplace=True)
validation_final.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       business_code cust_number clear_date document_create_date.1 due_in_date  \
# 36880          U001  0200230690 2019-12-02             2019-11-19  2019-12-09
# 36881          CA02  0140104409 2019-12-06             2019-11-19  2019-12-08
# 36882          U001  0200744019 2019-12-05             2019-11-19  2019-12-04
# 36883          U001  0200769623 2019-12-02             2019-11-19  2019-12-04
# 36884          U001  0200705742 2019-12-04             2019-11-19  2019-12-04
#
#        total_open_amount cust_payment_terms   DELAY
# 36880           455.6400               NAM4 -7 days
# 36881         72749.0166               CA10 -2 days
# 36882        102106.9300               NAA8  1 days
# 36883         20139.7400               NAH4 -2 days
# 36884         16980.6100               NAA8  0 days

# %%
# validation_final['clear_date_month_quarter'] = validation_final['clear_date'].dt.quarter
validation_final['document_create_date.1_month_quarter'] = validation_final['document_create_date.1'].dt.quarter
validation_final['due_in_date_month_quarter'] = validation_final['due_in_date'].dt.quarter
validation_final['document_create_date.1_month'] = validation_final['document_create_date.1'].dt.month
validation_final['due_in_date_month'] = validation_final['due_in_date'].dt.month
validation_final.head()
# Out:
# <ipython-input-49-96b210aca66c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['document_create_date.1_month_quarter'] = validation_final['document_create_date.1'].dt.quarter
# <ipython-input-49-96b210aca66c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['due_in_date_month_quarter'] = validation_final['due_in_date'].dt.quarter
# <ipython-input-49-96b210aca66c>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['document_create_date.1_month'] = validation_final['document_create_date.1'].dt.month
# <ipython-input-49-96b210aca66c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['due_in_date_month'] = validation_final['due_in_date'].dt.month
#       business_code cust_number clear_date document_create_date.1 due_in_date  \
# 36880          U001  0200230690 2019-12-02             2019-11-19  2019-12-09
# 36881          CA02  0140104409 2019-12-06             2019-11-19  2019-12-08
# 36882          U001  0200744019 2019-12-05             2019-11-19  2019-12-04
# 36883          U001  0200769623 2019-12-02             2019-11-19  2019-12-04
# 36884          U001  0200705742 2019-12-04             2019-11-19  2019-12-04
#
#        total_open_amount cust_payment_terms   DELAY  \
# 36880           455.6400               NAM4 -7 days
# 36881         72749.0166               CA10 -2 days
# 36882        102106.9300               NAA8  1 days
# 36883         20139.7400               NAH4 -2 days
# 36884         16980.6100               NAA8  0 days
#
#        document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 36880                                     4                          4
# 36881                                     4                          4
# 36882                                     4                          4
# 36883                                     4                          4
# 36884                                     4                          4
#
#        document_create_date.1_month  due_in_date_month
# 36880                            11                 12
# 36881                            11                 12
# 36882                            11                 12
# 36883                            11                 12
# 36884                            11                 12

# %%
labelencoder = LabelEncoder()
validation_final.iloc[:,0] = labelencoder.fit_transform(validation_final.iloc[:,0])
validation_final.iloc[:,1] = labelencoder.fit_transform(validation_final.iloc[:,1])
validation_final.iloc[:,6] = labelencoder.fit_transform(validation_final.iloc[:,6])
validation_final.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#        business_code  cust_number clear_date document_create_date.1  \
# 36880              1          168 2019-12-02             2019-11-19
# 36881              0          110 2019-12-06             2019-11-19
# 36882              1          298 2019-12-05             2019-11-19
# 36883              1          330 2019-12-02             2019-11-19
# 36884              1          243 2019-12-04             2019-11-19
#
#       due_in_date  total_open_amount  cust_payment_terms   DELAY  \
# 36880  2019-12-09           455.6400                  22 -7 days
# 36881  2019-12-08         72749.0166                   1 -2 days
# 36882  2019-12-04        102106.9300                   9  1 days
# 36883  2019-12-04         20139.7400                  19 -2 days
# 36884  2019-12-04         16980.6100                   9  0 days
#
#        document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 36880                                     4                          4
# 36881                                     4                          4
# 36882                                     4                          4
# 36883                                     4                          4
# 36884                                     4                          4
#
#        document_create_date.1_month  due_in_date_month
# 36880                            11                 12
# 36881                            11                 12
# 36882                            11                 12
# 36883                            11                 12
# 36884                            11                 12

# %%
validation_final.drop(columns=['clear_date','document_create_date.1','due_in_date'],inplace=True)
validation_final['DELAY'] = validation_final['DELAY'].dt.days
validation_final.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-51-accb44c9d736>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_final['DELAY'] = validation_final['DELAY'].dt.days
#        business_code  cust_number  total_open_amount  cust_payment_terms  \
# 36880              1          168           455.6400                  22
# 36881              0          110         72749.0166                   1
# 36882              1          298        102106.9300                   9
# 36883              1          330         20139.7400                  19
# 36884              1          243         16980.6100                   9
#
#        DELAY  document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 36880     -7                                     4                          4
# 36881     -2                                     4                          4
# 36882      1                                     4                          4
# 36883     -2                                     4                          4
# 36884      0                                     4                          4
#
#        document_create_date.1_month  due_in_date_month
# 36880                            11                 12
# 36881                            11                 12
# 36882                            11                 12
# 36883                            11                 12
# 36884                            11                 12

# %% [markdown]
# #### preparation in test_final dataframe for fitting into model

# %%
test_final.head()
# Out:
#       business_code cust_number   name_customer           clear_date  \
# 41490          CA02  0140104409  LOB associates  2020-01-24 00:00:00
# 41491          U001  0200236570         JACMAR   2020-02-19 00:00:00
# 41492          U001  0200769623      WAL-MAR us  2020-01-24 00:00:00
# 41493          U001  0200762301       C&S WH us  2020-01-29 00:00:00
# 41494          U001  0200772670       ASSOCIAT   2020-01-29 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 41490         2020.0  2.960607e+09   2020-01-14              20200114
# 41491         2020.0  1.930400e+09   2020-01-14              20200115
# 41492         2020.0  1.930396e+09   2020-01-14              20200114
# 41493         2020.0  1.930392e+09   2020-01-14              20200113
# 41494         2020.0  1.930397e+09   2020-01-14              20200114
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 41490                20200114   20200201.0              CAD            RV
# 41491                20200114   20200215.0              USD            RV
# 41492                20200114   20200129.0              USD            RV
# 41493                20200114   20200129.0              USD            RV
# 41494                20200114   20200129.0              USD            RV
#
#        posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 41490         1.0          346010.50            20200122.0               CA10
# 41491         1.0           65598.60            20200114.0               NA32
# 41492         1.0            6532.60            20200114.0               NAH4
# 41493         1.0           45330.31            20200114.0               NAC6
# 41494         1.0            8754.91            20200114.0               NAU5
#
#        isOpen
# 41490       0
# 41491       0
# 41492       0
# 41493       0
# 41494       0

# %%
test_final.drop(columns=['buisness_year','posting_id','isOpen'],inplace=True)
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
test_final.drop(columns=['document_create_date','baseline_create_date'],inplace=True)

# %%
test_final['clear_date'] = pd.to_datetime(test_final['clear_date'])
test_final['posting_date'] = pd.to_datetime(test_final['posting_date']) 
test_final['document_create_date.1'] = pd.to_datetime(test_final['document_create_date.1'], format='%Y%m%d')
test_final['due_in_date'] = pd.to_datetime(test_final['due_in_date'], format='%Y%m%d')
test_final.head()
# Out:
# <ipython-input-55-c03362d78a3a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['clear_date'] = pd.to_datetime(test_final['clear_date'])
# <ipython-input-55-c03362d78a3a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['posting_date'] = pd.to_datetime(test_final['posting_date'])
# <ipython-input-55-c03362d78a3a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['document_create_date.1'] = pd.to_datetime(test_final['document_create_date.1'], format='%Y%m%d')
# <ipython-input-55-c03362d78a3a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['due_in_date'] = pd.to_datetime(test_final['due_in_date'], format='%Y%m%d')
#       business_code cust_number   name_customer clear_date        doc_id  \
# 41490          CA02  0140104409  LOB associates 2020-01-24  2.960607e+09
# 41491          U001  0200236570         JACMAR  2020-02-19  1.930400e+09
# 41492          U001  0200769623      WAL-MAR us 2020-01-24  1.930396e+09
# 41493          U001  0200762301       C&S WH us 2020-01-29  1.930392e+09
# 41494          U001  0200772670       ASSOCIAT  2020-01-29  1.930397e+09
#
#       posting_date document_create_date.1 due_in_date invoice_currency  \
# 41490   2020-01-14             2020-01-14  2020-02-01              CAD
# 41491   2020-01-14             2020-01-14  2020-02-15              USD
# 41492   2020-01-14             2020-01-14  2020-01-29              USD
# 41493   2020-01-14             2020-01-14  2020-01-29              USD
# 41494   2020-01-14             2020-01-14  2020-01-29              USD
#
#       document type  total_open_amount cust_payment_terms
# 41490            RV          346010.50               CA10
# 41491            RV           65598.60               NA32
# 41492            RV            6532.60               NAH4
# 41493            RV           45330.31               NAC6
# 41494            RV            8754.91               NAU5

# %%
test_final.drop(columns=['posting_date'],inplace=True)
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
test_final['DELAY']=test_final['clear_date'] - test_final['due_in_date']
test_final.head()
# Out:
# <ipython-input-57-adafda3c7aae>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['DELAY']=test_final['clear_date'] - test_final['due_in_date']
#       business_code cust_number   name_customer clear_date        doc_id  \
# 41490          CA02  0140104409  LOB associates 2020-01-24  2.960607e+09
# 41491          U001  0200236570         JACMAR  2020-02-19  1.930400e+09
# 41492          U001  0200769623      WAL-MAR us 2020-01-24  1.930396e+09
# 41493          U001  0200762301       C&S WH us 2020-01-29  1.930392e+09
# 41494          U001  0200772670       ASSOCIAT  2020-01-29  1.930397e+09
#
#       document_create_date.1 due_in_date invoice_currency document type  \
# 41490             2020-01-14  2020-02-01              CAD            RV
# 41491             2020-01-14  2020-02-15              USD            RV
# 41492             2020-01-14  2020-01-29              USD            RV
# 41493             2020-01-14  2020-01-29              USD            RV
# 41494             2020-01-14  2020-01-29              USD            RV
#
#        total_open_amount cust_payment_terms   DELAY
# 41490          346010.50               CA10 -8 days
# 41491           65598.60               NA32  4 days
# 41492            6532.60               NAH4 -5 days
# 41493           45330.31               NAC6  0 days
# 41494            8754.91               NAU5  0 days

# %%
test_final['total_open_amount'] = np.where((test_final['invoice_currency'] == 'CAD') ,((test_final['total_open_amount'])*0.78),(test_final['total_open_amount']))
test_final.drop(columns=['invoice_currency'],inplace=True)
test_final.head()
# Out:
# <ipython-input-58-bd4180d47bb8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['total_open_amount'] = np.where((test_final['invoice_currency'] == 'CAD') ,((test_final['total_open_amount'])*0.78),(test_final['total_open_amount']))
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       business_code cust_number   name_customer clear_date        doc_id  \
# 41490          CA02  0140104409  LOB associates 2020-01-24  2.960607e+09
# 41491          U001  0200236570         JACMAR  2020-02-19  1.930400e+09
# 41492          U001  0200769623      WAL-MAR us 2020-01-24  1.930396e+09
# 41493          U001  0200762301       C&S WH us 2020-01-29  1.930392e+09
# 41494          U001  0200772670       ASSOCIAT  2020-01-29  1.930397e+09
#
#       document_create_date.1 due_in_date document type  total_open_amount  \
# 41490             2020-01-14  2020-02-01            RV          269888.19
# 41491             2020-01-14  2020-02-15            RV           65598.60
# 41492             2020-01-14  2020-01-29            RV            6532.60
# 41493             2020-01-14  2020-01-29            RV           45330.31
# 41494             2020-01-14  2020-01-29            RV            8754.91
#
#       cust_payment_terms   DELAY
# 41490               CA10 -8 days
# 41491               NA32  4 days
# 41492               NAH4 -5 days
# 41493               NAC6  0 days
# 41494               NAU5  0 days

# %%
test_final.drop(columns=['doc_id','document type','name_customer'],inplace=True)
test_final.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       business_code cust_number clear_date document_create_date.1 due_in_date  \
# 41490          CA02  0140104409 2020-01-24             2020-01-14  2020-02-01
# 41491          U001  0200236570 2020-02-19             2020-01-14  2020-02-15
# 41492          U001  0200769623 2020-01-24             2020-01-14  2020-01-29
# 41493          U001  0200762301 2020-01-29             2020-01-14  2020-01-29
# 41494          U001  0200772670 2020-01-29             2020-01-14  2020-01-29
#
#        total_open_amount cust_payment_terms   DELAY
# 41490          269888.19               CA10 -8 days
# 41491           65598.60               NA32  4 days
# 41492            6532.60               NAH4 -5 days
# 41493           45330.31               NAC6  0 days
# 41494            8754.91               NAU5  0 days

# %%
test_final['document_create_date.1_month_quarter'] = test_final['document_create_date.1'].dt.quarter
test_final['due_in_date_month_quarter'] = test_final['due_in_date'].dt.quarter
test_final['document_create_date.1_month'] = test_final['document_create_date.1'].dt.month
test_final['due_in_date_month'] = test_final['due_in_date'].dt.month
test_final.head()
# Out:
# <ipython-input-60-821ba5ae015f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['document_create_date.1_month_quarter'] = test_final['document_create_date.1'].dt.quarter
# <ipython-input-60-821ba5ae015f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['due_in_date_month_quarter'] = test_final['due_in_date'].dt.quarter
# <ipython-input-60-821ba5ae015f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['document_create_date.1_month'] = test_final['document_create_date.1'].dt.month
# <ipython-input-60-821ba5ae015f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['due_in_date_month'] = test_final['due_in_date'].dt.month
#       business_code cust_number clear_date document_create_date.1 due_in_date  \
# 41490          CA02  0140104409 2020-01-24             2020-01-14  2020-02-01
# 41491          U001  0200236570 2020-02-19             2020-01-14  2020-02-15
# 41492          U001  0200769623 2020-01-24             2020-01-14  2020-01-29
# 41493          U001  0200762301 2020-01-29             2020-01-14  2020-01-29
# 41494          U001  0200772670 2020-01-29             2020-01-14  2020-01-29
#
#        total_open_amount cust_payment_terms   DELAY  \
# 41490          269888.19               CA10 -8 days
# 41491           65598.60               NA32  4 days
# 41492            6532.60               NAH4 -5 days
# 41493           45330.31               NAC6  0 days
# 41494            8754.91               NAU5  0 days
#
#        document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 41490                                     1                          1
# 41491                                     1                          1
# 41492                                     1                          1
# 41493                                     1                          1
# 41494                                     1                          1
#
#        document_create_date.1_month  due_in_date_month
# 41490                             1                  2
# 41491                             1                  2
# 41492                             1                  1
# 41493                             1                  1
# 41494                             1                  1

# %%
labelencoder = LabelEncoder()
test_final.iloc[:,0] = labelencoder.fit_transform(test_final.iloc[:,0])
test_final.iloc[:,1] = labelencoder.fit_transform(test_final.iloc[:,1])
test_final.iloc[:,6] = labelencoder.fit_transform(test_final.iloc[:,6])
test_final.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#        business_code  cust_number clear_date document_create_date.1  \
# 41490              0          118 2020-01-24             2020-01-14
# 41491              1          182 2020-02-19             2020-01-14
# 41492              1          355 2020-01-24             2020-01-14
# 41493              1          343 2020-01-29             2020-01-14
# 41494              1          359 2020-01-29             2020-01-14
#
#       due_in_date  total_open_amount  cust_payment_terms   DELAY  \
# 41490  2020-02-01          269888.19                   3 -8 days
# 41491  2020-02-15           65598.60                   7  4 days
# 41492  2020-01-29            6532.60                  25 -5 days
# 41493  2020-01-29           45330.31                  17  0 days
# 41494  2020-01-29            8754.91                  30  0 days
#
#        document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 41490                                     1                          1
# 41491                                     1                          1
# 41492                                     1                          1
# 41493                                     1                          1
# 41494                                     1                          1
#
#        document_create_date.1_month  due_in_date_month
# 41490                             1                  2
# 41491                             1                  2
# 41492                             1                  1
# 41493                             1                  1
# 41494                             1                  1

# %%
test_final.drop(columns=['clear_date','document_create_date.1','due_in_date'],inplace=True)
test_final['DELAY'] = test_final['DELAY'].dt.days
test_final.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# <ipython-input-62-853462303bf9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_final['DELAY'] = test_final['DELAY'].dt.days
#        business_code  cust_number  total_open_amount  cust_payment_terms  \
# 41490              0          118          269888.19                   3
# 41491              1          182           65598.60                   7
# 41492              1          355            6532.60                  25
# 41493              1          343           45330.31                  17
# 41494              1          359            8754.91                  30
#
#        DELAY  document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 41490     -8                                     1                          1
# 41491      4                                     1                          1
# 41492     -5                                     1                          1
# 41493      0                                     1                          1
# 41494      0                                     1                          1
#
#        document_create_date.1_month  due_in_date_month
# 41490                             1                  2
# 41491                             1                  2
# 41492                             1                  1
# 41493                             1                  1
# 41494                             1                  1

# %% [markdown]
# #### preparetion in test  dataframe for fitting into model

# %%
test.drop(columns=['area_business','invoice_id'],inplace=True)
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
test.head()
# Out:
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co        NaN
# 46102          U001  0200762301    C&S WH associates        NaN
# 46103          U001  0200769623             WAL-MAR         NaN
# 46104          U001  0200769623  WAL-MAR corporation        NaN
# 46105          U001  0200769623           WAL-MAR in        NaN
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 46101                20200409   20200424.0              USD            RV
# 46102                20200304   20200319.0              USD            RV
# 46103                20200318   20200402.0              USD            RV
# 46104                20200308   20200323.0              USD            RV
# 46105                20200325   20200409.0              USD            RV
#
#        posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 46101         1.0           21254.12            20200409.0               NAC6
# 46102         1.0           48510.63            20200304.0               NAC6
# 46103         1.0           15451.48            20200318.0               NAH4
# 46104         1.0           33731.82            20200308.0               NAH4
# 46105         1.0            1898.20            20200325.0               NAH4
#
#        isOpen
# 46101       1
# 46102       1
# 46103       1
# 46104       1
# 46105       1

# %%
test.drop(columns=['buisness_year','posting_id','isOpen'],inplace=True)
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
test.drop(columns=['document_create_date','baseline_create_date'],inplace=True)

# %%
test['clear_date'] = pd.to_datetime(test['clear_date'])
test['posting_date'] = pd.to_datetime(test['posting_date']) 
test['document_create_date.1'] = pd.to_datetime(test['document_create_date.1'], format='%Y%m%d')
test['due_in_date'] = pd.to_datetime(test['due_in_date'], format='%Y%m%d')
test.head()
# Out:
# <ipython-input-67-c5b2c65d5eff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['clear_date'] = pd.to_datetime(test['clear_date'])
# <ipython-input-67-c5b2c65d5eff>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['posting_date'] = pd.to_datetime(test['posting_date'])
# <ipython-input-67-c5b2c65d5eff>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['document_create_date.1'] = pd.to_datetime(test['document_create_date.1'], format='%Y%m%d')
# <ipython-input-67-c5b2c65d5eff>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['due_in_date'] = pd.to_datetime(test['due_in_date'], format='%Y%m%d')
#       business_code cust_number        name_customer clear_date        doc_id  \
# 46101          U001  0200762301            C&S WH co        NaT  1.930760e+09
# 46102          U001  0200762301    C&S WH associates        NaT  1.930594e+09
# 46103          U001  0200769623             WAL-MAR         NaT  1.930658e+09
# 46104          U001  0200769623  WAL-MAR corporation        NaT  1.930620e+09
# 46105          U001  0200769623           WAL-MAR in        NaT  1.930690e+09
#
#       posting_date document_create_date.1 due_in_date invoice_currency  \
# 46101   2020-04-09             2020-04-09  2020-04-24              USD
# 46102   2020-03-04             2020-03-04  2020-03-19              USD
# 46103   2020-03-18             2020-03-18  2020-04-02              USD
# 46104   2020-03-08             2020-03-08  2020-03-23              USD
# 46105   2020-03-25             2020-03-25  2020-04-09              USD
#
#       document type  total_open_amount cust_payment_terms
# 46101            RV           21254.12               NAC6
# 46102            RV           48510.63               NAC6
# 46103            RV           15451.48               NAH4
# 46104            RV           33731.82               NAH4
# 46105            RV            1898.20               NAH4

# %%
test.drop(columns=['posting_date'],inplace=True)
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
test['total_open_amount'] = np.where((test['invoice_currency'] == 'CAD') ,((test['total_open_amount'])*0.78),(test['total_open_amount']))
test.drop(columns=['invoice_currency'],inplace=True)
test.head()
# Out:
# <ipython-input-69-7ca903955f29>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['total_open_amount'] = np.where((test['invoice_currency'] == 'CAD') ,((test['total_open_amount'])*0.78),(test['total_open_amount']))
#       business_code cust_number        name_customer clear_date        doc_id  \
# 46101          U001  0200762301            C&S WH co        NaT  1.930760e+09
# 46102          U001  0200762301    C&S WH associates        NaT  1.930594e+09
# 46103          U001  0200769623             WAL-MAR         NaT  1.930658e+09
# 46104          U001  0200769623  WAL-MAR corporation        NaT  1.930620e+09
# 46105          U001  0200769623           WAL-MAR in        NaT  1.930690e+09
#
#       document_create_date.1 due_in_date document type  total_open_amount  \
# 46101             2020-04-09  2020-04-24            RV           21254.12
# 46102             2020-03-04  2020-03-19            RV           48510.63
# 46103             2020-03-18  2020-04-02            RV           15451.48
# 46104             2020-03-08  2020-03-23            RV           33731.82
# 46105             2020-03-25  2020-04-09            RV            1898.20
#
#       cust_payment_terms
# 46101               NAC6
# 46102               NAC6
# 46103               NAH4
# 46104               NAH4
# 46105               NAH4

# %%
test.drop(columns=['doc_id','document type','name_customer'],inplace=True)
test.head()
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#       business_code cust_number clear_date document_create_date.1 due_in_date  \
# 46101          U001  0200762301        NaT             2020-04-09  2020-04-24
# 46102          U001  0200762301        NaT             2020-03-04  2020-03-19
# 46103          U001  0200769623        NaT             2020-03-18  2020-04-02
# 46104          U001  0200769623        NaT             2020-03-08  2020-03-23
# 46105          U001  0200769623        NaT             2020-03-25  2020-04-09
#
#        total_open_amount cust_payment_terms
# 46101           21254.12               NAC6
# 46102           48510.63               NAC6
# 46103           15451.48               NAH4
# 46104           33731.82               NAH4
# 46105            1898.20               NAH4

# %%
test['document_create_date.1_month_quarter'] = test['document_create_date.1'].dt.quarter
test['due_in_date_month_quarter'] = test['due_in_date'].dt.quarter
test['document_create_date.1_month'] = test['document_create_date.1'].dt.month
test['due_in_date_month'] = test['due_in_date'].dt.month
test.head()
# Out:
# <ipython-input-71-15c5b4227100>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['document_create_date.1_month_quarter'] = test['document_create_date.1'].dt.quarter
# <ipython-input-71-15c5b4227100>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['due_in_date_month_quarter'] = test['due_in_date'].dt.quarter
# <ipython-input-71-15c5b4227100>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['document_create_date.1_month'] = test['document_create_date.1'].dt.month
# <ipython-input-71-15c5b4227100>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['due_in_date_month'] = test['due_in_date'].dt.month
#       business_code cust_number clear_date document_create_date.1 due_in_date  \
# 46101          U001  0200762301        NaT             2020-04-09  2020-04-24
# 46102          U001  0200762301        NaT             2020-03-04  2020-03-19
# 46103          U001  0200769623        NaT             2020-03-18  2020-04-02
# 46104          U001  0200769623        NaT             2020-03-08  2020-03-23
# 46105          U001  0200769623        NaT             2020-03-25  2020-04-09
#
#        total_open_amount cust_payment_terms  \
# 46101           21254.12               NAC6
# 46102           48510.63               NAC6
# 46103           15451.48               NAH4
# 46104           33731.82               NAH4
# 46105            1898.20               NAH4
#
#        document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 46101                                     2                          2
# 46102                                     1                          1
# 46103                                     1                          2
# 46104                                     1                          1
# 46105                                     1                          2
#
#        document_create_date.1_month  due_in_date_month
# 46101                             4                  4
# 46102                             3                  3
# 46103                             3                  4
# 46104                             3                  3
# 46105                             3                  4

# %%
labelencoder = LabelEncoder()
test.iloc[:,0] = labelencoder.fit_transform(test.iloc[:,0])
test.iloc[:,1] = labelencoder.fit_transform(test.iloc[:,1])
test.iloc[:,6] = labelencoder.fit_transform(test.iloc[:,6])
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
test.drop(columns=['clear_date','document_create_date.1','due_in_date'],inplace=True)
# Out:
# c:\users\telecom division\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
test.head()
# Out:
#        business_code  cust_number  total_open_amount  cust_payment_terms  \
# 46101              1          263           21254.12                  14
# 46102              1          263           48510.63                  14
# 46103              1          275           15451.48                  21
# 46104              1          275           33731.82                  21
# 46105              1          275            1898.20                  21
#
#        document_create_date.1_month_quarter  due_in_date_month_quarter  \
# 46101                                     2                          2
# 46102                                     1                          1
# 46103                                     1                          2
# 46104                                     1                          1
# 46105                                     1                          2
#
#        document_create_date.1_month  due_in_date_month
# 46101                             4                  4
# 46102                             3                  3
# 46103                             3                  4
# 46104                             3                  3
# 46105                             3                  4

# %% [markdown]
# #### Spliting

# %%
#spliting train_final
X_train, X_test, y_train, y_test = train_test_split(
    train_final.drop(labels=['DELAY'], axis=1),
    train_final['DELAY'],
    test_size=0.3,
    random_state=False)

# %%
#spliting validation_final
X_validation_final_test = validation_final.drop(labels=['DELAY'], axis=1)
y_validation_final_test = validation_final['DELAY']
X_validation_final_test.shape,y_validation_final_test.shape
# Out:
# ((4610, 8), (4610,))

# %%
#spliting test_final
X_test_final_test = test_final.drop(labels=['DELAY'], axis=1)
y_test_final_test = test_final['DELAY']
X_test_final_test.shape,y_test_final_test.shape
# Out:
# ((4611, 8), (4611,))

# %% [markdown]
# ### Modelling

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
# checking model in train_final
model_1 = LinearRegression()
model_1.fit(X_train_scaled,y_train)
pred_value = model_1.predict(X_test_scaled)
print(f'score = {model_1.score(X_test_scaled,y_test)}')
print(f'r2_score = {r2_score(y_test,pred_value)}')
print(f'mean_squared_error = {mean_squared_error(y_test, pred_value)}')
root_mean_square_error=sqrt(mean_squared_error(y_test, pred_value))
print(f'root_mean_square_error = {root_mean_square_error}')
# Out:
# score = 0.013783282199210878
# r2_score = 0.013783282199210878
# mean_squared_error = 121.0316539723928
# root_mean_square_error = 11.001438722839518

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_validation_final_test_scaled = scaler.fit_transform(X_validation_final_test)

# %%
# checking model in validation_final
pred_value_validation = model_1.predict(X_validation_final_test_scaled)
print(f'score = {model_1.score(X_validation_final_test_scaled,y_validation_final_test)}')
print(f'r2_score = {r2_score(y_validation_final_test,pred_value_validation)}')
print(f'mean_squared_error = {mean_squared_error(y_validation_final_test, pred_value_validation)}')
root_mean_square_error_validation=sqrt(mean_squared_error(y_validation_final_test, pred_value_validation))
print(f'root_mean_square_error = {root_mean_square_error_validation}')
# Out:
# score = -0.1585434011459146
# r2_score = -0.1585434011459146
# mean_squared_error = 71.46125138062975
# root_mean_square_error = 8.453475698233818

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_test_final_scaled = scaler.fit_transform(X_test_final_test)

# %%
# checking model in test_final
pred_value_test_final = model_1.predict(X_test_final_scaled)
print(f'score = {model_1.score(X_test_final_scaled,y_test_final_test)}')
print(f'r2_score = {r2_score(y_test_final_test,pred_value_test_final)}')
print(f'mean_squared_error = {mean_squared_error(y_test_final_test, pred_value_test_final)}')
root_mean_square_error_test_final=sqrt(mean_squared_error(y_test_final_test, pred_value_test_final))
print(f'root_mean_square_error = {root_mean_square_error_test_final}')
# Out:
# score = 0.031724231364475663
# r2_score = 0.031724231364475663
# mean_squared_error = 108.32777124813711
# root_mean_square_error = 10.408062799970853

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
test_scaled = scaler.fit_transform(test)

# %%
# checking model in test for prediction
pred_value_test = model_1.predict(test_scaled)
pred_value_test
# Out:
# array([ 2.76404868,  3.30683615,  0.06165918, ...,  3.50546186,
#        -1.76450313,  2.96044918])

# %%
# delay is added to raw test data
temp_test_data['delay'] = pred_value_test
# Out:
# <ipython-input-86-8309cce8e7c0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay'] = pred_value_test

# %%
temp_test_data.head()
# Out:
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co        NaN
# 46102          U001  0200762301    C&S WH associates        NaN
# 46103          U001  0200769623             WAL-MAR         NaN
# 46104          U001  0200769623  WAL-MAR corporation        NaN
# 46105          U001  0200769623           WAL-MAR in        NaN
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 46101                20200409   20200424.0              USD            RV
# 46102                20200304   20200319.0              USD            RV
# 46103                20200318   20200402.0              USD            RV
# 46104                20200308   20200323.0              USD            RV
# 46105                20200325   20200409.0              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 46101         1.0            NaN           21254.12            20200409.0
# 46102         1.0            NaN           48510.63            20200304.0
# 46103         1.0            NaN           15451.48            20200318.0
# 46104         1.0            NaN           33731.82            20200308.0
# 46105         1.0            NaN            1898.20            20200325.0
#
#       cust_payment_terms    invoice_id  isOpen     delay
# 46101               NAC6  1.930760e+09       1  2.764049
# 46102               NAC6  1.930594e+09       1  3.306836
# 46103               NAH4  1.930658e+09       1  0.061659
# 46104               NAH4  1.930620e+09       1  4.053832
# 46105               NAH4  1.930690e+09       1  0.063368

# %%
#now clear_date,due_in_date are converted to datetime format for predicting the clear_date
temp_test_data['clear_date'] = pd.to_datetime(temp_test_data['clear_date'])
temp_test_data['due_in_date'] = pd.to_datetime(temp_test_data['due_in_date'], format='%Y%m%d')
temp_test_data.head()
# Out:
# <ipython-input-88-eaf763d173fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['clear_date'] = pd.to_datetime(temp_test_data['clear_date'])
# <ipython-input-88-eaf763d173fd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['due_in_date'] = pd.to_datetime(temp_test_data['due_in_date'], format='%Y%m%d')
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co        NaT
# 46102          U001  0200762301    C&S WH associates        NaT
# 46103          U001  0200769623             WAL-MAR         NaT
# 46104          U001  0200769623  WAL-MAR corporation        NaT
# 46105          U001  0200769623           WAL-MAR in        NaT
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date invoice_currency document type  \
# 46101                20200409  2020-04-24              USD            RV
# 46102                20200304  2020-03-19              USD            RV
# 46103                20200318  2020-04-02              USD            RV
# 46104                20200308  2020-03-23              USD            RV
# 46105                20200325  2020-04-09              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 46101         1.0            NaN           21254.12            20200409.0
# 46102         1.0            NaN           48510.63            20200304.0
# 46103         1.0            NaN           15451.48            20200318.0
# 46104         1.0            NaN           33731.82            20200308.0
# 46105         1.0            NaN            1898.20            20200325.0
#
#       cust_payment_terms    invoice_id  isOpen     delay
# 46101               NAC6  1.930760e+09       1  2.764049
# 46102               NAC6  1.930594e+09       1  3.306836
# 46103               NAH4  1.930658e+09       1  0.061659
# 46104               NAH4  1.930620e+09       1  4.053832
# 46105               NAH4  1.930690e+09       1  0.063368

# %%
#prediction for clear_date
temp = temp_test_data['delay'].apply(np.ceil).apply(lambda x: pd.Timedelta(x, unit='D'))
temp_test_data['clear_date'] = temp_test_data['due_in_date'] + temp
# Out:
# <ipython-input-89-cc6340f03afa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['clear_date'] = temp_test_data['due_in_date'] + temp

# %%
# converted the delay into ceiling format
temp_test_data['delay'] = np.ceil(temp_test_data['delay'])
# Out:
# <ipython-input-90-fa4d2e95f06e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay'] = np.ceil(temp_test_data['delay'])

# %%
temp_test_data.head()
# Out:
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-04-27
# 46102          U001  0200762301    C&S WH associates 2020-03-23
# 46103          U001  0200769623             WAL-MAR  2020-04-03
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-28
# 46105          U001  0200769623           WAL-MAR in 2020-04-10
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date invoice_currency document type  \
# 46101                20200409  2020-04-24              USD            RV
# 46102                20200304  2020-03-19              USD            RV
# 46103                20200318  2020-04-02              USD            RV
# 46104                20200308  2020-03-23              USD            RV
# 46105                20200325  2020-04-09              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 46101         1.0            NaN           21254.12            20200409.0
# 46102         1.0            NaN           48510.63            20200304.0
# 46103         1.0            NaN           15451.48            20200318.0
# 46104         1.0            NaN           33731.82            20200308.0
# 46105         1.0            NaN            1898.20            20200325.0
#
#       cust_payment_terms    invoice_id  isOpen  delay
# 46101               NAC6  1.930760e+09       1    3.0
# 46102               NAC6  1.930594e+09       1    4.0
# 46103               NAH4  1.930658e+09       1    1.0
# 46104               NAH4  1.930620e+09       1    5.0
# 46105               NAH4  1.930690e+09       1    1.0

# %%
#buckting
l1 = temp_test_data['delay'].tolist() # pd series to list conversion
l2 = [] # empty list which will hold the bucket value
for x in l1:
    if x < 0:
        l2.append('< 0 days')
    elif x >= 0 and x <= 15:
        l2.append('0-15 days')
    elif x >= 16 and x <= 30:
        l2.append('16-30 days')
    elif x >=31 and x <= 45:
        l2.append('31-45 days')
    elif x >=46 and x <= 60:
        l2.append('46-60 days')
    else:
        l2.append('> 60 days')

# %%
temp_test_data['delay_bucket'] = l2
temp_test_data.head()
# Out:
# <ipython-input-93-a5c2dad2e7bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay_bucket'] = l2
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-04-27
# 46102          U001  0200762301    C&S WH associates 2020-03-23
# 46103          U001  0200769623             WAL-MAR  2020-04-03
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-28
# 46105          U001  0200769623           WAL-MAR in 2020-04-10
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1    3.0     0-15 days
# 46102                NAC6  1.930594e+09       1    4.0     0-15 days
# 46103                NAH4  1.930658e+09       1    1.0     0-15 days
# 46104                NAH4  1.930620e+09       1    5.0     0-15 days
# 46105                NAH4  1.930690e+09       1    1.0     0-15 days
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Support Vector Regression

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
# checking model in train_final
model_2 = SVR()
model_2.fit(X_train_scaled,y_train)
pred_value = model_2.predict(X_test_scaled)
print(f'score = {model_2.score(X_test_scaled,y_test)}')
print(f'r2_score = {r2_score(y_test,pred_value)}')
print(f'mean_squared_error = {mean_squared_error(y_test, pred_value)}')
root_mean_square_error=sqrt(mean_squared_error(y_test, pred_value))
print(f'root_mean_square_error = {root_mean_square_error}')
# Out:
# score = 0.2607184121226148
# r2_score = 0.2607184121226148
# mean_squared_error = 90.72698902495242
# root_mean_square_error = 9.52507160209058

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
test_scaled = scaler.fit_transform(test)

# %%
# checking model in validation_final
pred_value_validation = model_2.predict(X_validation_final_test_scaled)
print(f'score = {model_2.score(X_validation_final_test_scaled,y_validation_final_test)}')
print(f'r2_score = {r2_score(y_validation_final_test,pred_value_validation)}')
print(f'mean_squared_error = {mean_squared_error(y_validation_final_test, pred_value_validation)}')
root_mean_square_error_validation=sqrt(mean_squared_error(y_validation_final_test, pred_value_validation))
print(f'root_mean_square_error = {root_mean_square_error_validation}')
# Out:
# score = 0.26498849587503204
# r2_score = 0.26498849587503204
# mean_squared_error = 45.33696520300994
# root_mean_square_error = 6.733272993352485

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_test_final_scaled = scaler.fit_transform(X_test_final_test)

# %%
# checking model in test_final
pred_value_test_final = model_2.predict(X_test_final_scaled)
print(f'score = {model_2.score(X_test_final_scaled,y_test_final_test)}')
print(f'r2_score = {r2_score(y_test_final_test,pred_value_test_final)}')
print(f'mean_squared_error = {mean_squared_error(y_test_final_test, pred_value_test_final)}')
root_mean_square_error_test_final=sqrt(mean_squared_error(y_test_final_test, pred_value_test_final))
print(f'root_mean_square_error = {root_mean_square_error_test_final}')
# Out:
# score = 0.1440123493494998
# r2_score = 0.1440123493494998
# mean_squared_error = 95.7653154344316
# root_mean_square_error = 9.785975446240993

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
test_scaled = scaler.fit_transform(test)

# %%
# checking model in test for prediction
pred_value_test = model_2.predict(test_scaled)
pred_value_test
# Out:
# array([-0.54643525, -0.95189254, -2.33620091, ..., -2.66295429,
#         0.49928892,  0.84371233])

# %%
# delay is added to raw test data
temp_test_data['delay'] = pred_value_test
temp_test_data.head()
# Out:
# <ipython-input-102-843f9afe623a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay'] = pred_value_test
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-04-27
# 46102          U001  0200762301    C&S WH associates 2020-03-23
# 46103          U001  0200769623             WAL-MAR  2020-04-03
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-28
# 46105          U001  0200769623           WAL-MAR in 2020-04-10
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen     delay  delay_bucket
# 46101                NAC6  1.930760e+09       1 -0.546435     0-15 days
# 46102                NAC6  1.930594e+09       1 -0.951893     0-15 days
# 46103                NAH4  1.930658e+09       1 -2.336201     0-15 days
# 46104                NAH4  1.930620e+09       1 -2.650259     0-15 days
# 46105                NAH4  1.930690e+09       1 -2.494018     0-15 days
#
# [5 rows x 21 columns]

# %%
#now clear_date,due_in_date are converted to datetime format for predicting the clear_date
temp_test_data['clear_date'] = pd.to_datetime(temp_test_data['clear_date'])
temp_test_data['due_in_date'] = pd.to_datetime(temp_test_data['due_in_date'], format='%Y%m%d')
temp_test_data.head()
# Out:
# <ipython-input-103-eaf763d173fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['clear_date'] = pd.to_datetime(temp_test_data['clear_date'])
# <ipython-input-103-eaf763d173fd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['due_in_date'] = pd.to_datetime(temp_test_data['due_in_date'], format='%Y%m%d')
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-04-27
# 46102          U001  0200762301    C&S WH associates 2020-03-23
# 46103          U001  0200769623             WAL-MAR  2020-04-03
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-28
# 46105          U001  0200769623           WAL-MAR in 2020-04-10
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen     delay  delay_bucket
# 46101                NAC6  1.930760e+09       1 -0.546435     0-15 days
# 46102                NAC6  1.930594e+09       1 -0.951893     0-15 days
# 46103                NAH4  1.930658e+09       1 -2.336201     0-15 days
# 46104                NAH4  1.930620e+09       1 -2.650259     0-15 days
# 46105                NAH4  1.930690e+09       1 -2.494018     0-15 days
#
# [5 rows x 21 columns]

# %%
#prediction for clear_date
temp = temp_test_data['delay'].apply(np.ceil).apply(lambda x: pd.Timedelta(x, unit='D'))
temp_test_data['clear_date'] = temp_test_data['due_in_date'] + temp
# Out:
# <ipython-input-104-cc6340f03afa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['clear_date'] = temp_test_data['due_in_date'] + temp

# %%
# converted the delay into ceiling format
temp_test_data['delay'] = np.ceil(temp_test_data['delay'])
temp_test_data.head()
# Out:
# <ipython-input-105-224da961840e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay'] = np.ceil(temp_test_data['delay'])
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-04-24
# 46102          U001  0200762301    C&S WH associates 2020-03-19
# 46103          U001  0200769623             WAL-MAR  2020-03-31
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-21
# 46105          U001  0200769623           WAL-MAR in 2020-04-07
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1   -0.0     0-15 days
# 46102                NAC6  1.930594e+09       1   -0.0     0-15 days
# 46103                NAH4  1.930658e+09       1   -2.0     0-15 days
# 46104                NAH4  1.930620e+09       1   -2.0     0-15 days
# 46105                NAH4  1.930690e+09       1   -2.0     0-15 days
#
# [5 rows x 21 columns]

# %%
#buckting
l1 = temp_test_data['delay'].tolist() # pd series to list conversion
l2 = [] # empty list which will hold the bucket value
for x in l1:
    if x < 0:
        l2.append('0-15 days')
    elif x >= 0 and x <= 15:
        l2.append('0-15 days')
    elif x >= 16 and x <= 30:
        l2.append('16-30 days')
    elif x >=31 and x <= 45:
        l2.append('31-45 days')
    elif x >=46 and x <= 60:
        l2.append('46-60 days')
    else:
        l2.append('> 60 days')

# %%
temp_test_data['delay_bucket'] = l2
temp_test_data.head()
# Out:
# <ipython-input-107-a5c2dad2e7bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay_bucket'] = l2
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-04-24
# 46102          U001  0200762301    C&S WH associates 2020-03-19
# 46103          U001  0200769623             WAL-MAR  2020-03-31
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-21
# 46105          U001  0200769623           WAL-MAR in 2020-04-07
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1   -0.0     0-15 days
# 46102                NAC6  1.930594e+09       1   -0.0     0-15 days
# 46103                NAH4  1.930658e+09       1   -2.0     0-15 days
# 46104                NAH4  1.930620e+09       1   -2.0     0-15 days
# 46105                NAH4  1.930690e+09       1   -2.0     0-15 days
#
# [5 rows x 21 columns]

# %%
temp_test_data.describe()
# Out:
#        buisness_year        doc_id  document_create_date  \
# count         3899.0  3.899000e+03          3.899000e+03
# mean          2020.0  2.000820e+09          2.020037e+07
# std              0.0  2.582422e+08          7.000721e+01
# min           2020.0  1.930535e+09          2.020022e+07
# 25%           2020.0  1.930660e+09          2.020032e+07
# 50%           2020.0  1.930732e+09          2.020033e+07
# 75%           2020.0  1.930819e+09          2.020042e+07
# max           2020.0  2.960635e+09          2.020052e+07
#
#        document_create_date.1  posting_id  area_business  total_open_amount  \
# count            3.899000e+03      3899.0            0.0        3899.000000
# mean             2.020037e+07         1.0            NaN       32924.807833
# std              6.948637e+01         0.0            NaN       36276.267032
# min              2.020023e+07         1.0            NaN           5.810000
# 25%              2.020032e+07         1.0            NaN        5495.415000
# 50%              2.020033e+07         1.0            NaN       19145.650000
# 75%              2.020042e+07         1.0            NaN       49259.525000
# max              2.020052e+07         1.0            NaN      292561.560000
#
#        baseline_create_date    invoice_id  isOpen        delay
# count          3.899000e+03  3.899000e+03  3899.0  3899.000000
# mean           2.020037e+07  2.000820e+09     1.0     0.643755
# std            6.931527e+01  2.582422e+08     0.0     3.047182
# min            2.020023e+07  1.930535e+09     1.0    -7.000000
# 25%            2.020032e+07  1.930660e+09     1.0    -2.000000
# 50%            2.020033e+07  1.930732e+09     1.0     1.000000
# 75%            2.020042e+07  1.930819e+09     1.0     2.000000
# max            2.020052e+07  2.960635e+09     1.0    25.000000

# %% [markdown]
# #### Decision Tree Regressor

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
# checking model in train_final
model_3 = DecisionTreeRegressor()
model_3.fit(X_train_scaled,y_train)
pred_value = model_3.predict(X_test_scaled)
print(f'score = {model_3.score(X_test_scaled,y_test)}')
print(f'r2_score = {r2_score(y_test,pred_value)}')
print(f'mean_squared_error = {mean_squared_error(y_test, pred_value)}')
root_mean_square_error=sqrt(mean_squared_error(y_test, pred_value))
print(f'root_mean_square_error = {root_mean_square_error}')
# Out:
# score = -0.25765496481252814
# r2_score = -0.25765496481252814
# mean_squared_error = 154.34341942335502
# root_mean_square_error = 12.423502703479201

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_validation_final_test_scaled = scaler.fit_transform(X_validation_final_test)

# %%
# checking model in validation_final
pred_value_validation = model_3.predict(X_validation_final_test_scaled)
print(f'score = {model_3.score(X_validation_final_test_scaled,y_validation_final_test)}')
print(f'r2_score = {r2_score(y_validation_final_test,pred_value_validation)}')
print(f'mean_squared_error = {mean_squared_error(y_validation_final_test, pred_value_validation)}')
root_mean_square_error_validation=sqrt(mean_squared_error(y_validation_final_test, pred_value_validation))
print(f'root_mean_square_error = {root_mean_square_error_validation}')
# Out:
# score = -2.5268177970831887
# r2_score = -2.5268177970831887
# mean_squared_error = 217.54110629067245
# root_mean_square_error = 14.7492747716853

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_test_final_scaled = scaler.fit_transform(X_test_final_test)

# %%
# checking model in test_final
pred_value_test_final = model_3.predict(X_test_final_scaled)
print(f'score = {model_3.score(X_test_final_scaled,y_test_final_test)}')
print(f'r2_score = {r2_score(y_test_final_test,pred_value_test_final)}')
print(f'mean_squared_error = {mean_squared_error(y_test_final_test, pred_value_test_final)}')
root_mean_square_error_test_final=sqrt(mean_squared_error(y_test_final_test, pred_value_test_final))
print(f'root_mean_square_error = {root_mean_square_error_test_final}')
# Out:
# score = -5.6786107992125245
# r2_score = -5.6786107992125245
# mean_squared_error = 747.1828236824983
# root_mean_square_error = 27.33464511718596

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
test_scaled = scaler.fit_transform(test)

# %%
# checking model in test for prediction
pred_value_test = model_3.predict(test_scaled)
pred_value_test
# Out:
# array([48., 48., -5., ..., -7., 90., -4.])

# %%
# delay is added to raw test data
temp_test_data['delay'] = pred_value_test
temp_test_data.head()
# Out:
# <ipython-input-117-843f9afe623a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay'] = pred_value_test
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-04-24
# 46102          U001  0200762301    C&S WH associates 2020-03-19
# 46103          U001  0200769623             WAL-MAR  2020-03-31
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-21
# 46105          U001  0200769623           WAL-MAR in 2020-04-07
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1   48.0     0-15 days
# 46102                NAC6  1.930594e+09       1   48.0     0-15 days
# 46103                NAH4  1.930658e+09       1   -5.0     0-15 days
# 46104                NAH4  1.930620e+09       1   -9.0     0-15 days
# 46105                NAH4  1.930690e+09       1   -5.0     0-15 days
#
# [5 rows x 21 columns]

# %%
#now clear_date,due_in_date are converted to datetime format for predicting the clear_date
temp_test_data['clear_date'] = pd.to_datetime(temp_test_data['clear_date'])
temp_test_data['due_in_date'] = pd.to_datetime(temp_test_data['due_in_date'], format='%Y%m%d')
temp_test_data.head()
# Out:
# <ipython-input-118-eaf763d173fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['clear_date'] = pd.to_datetime(temp_test_data['clear_date'])
# <ipython-input-118-eaf763d173fd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['due_in_date'] = pd.to_datetime(temp_test_data['due_in_date'], format='%Y%m%d')
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-04-24
# 46102          U001  0200762301    C&S WH associates 2020-03-19
# 46103          U001  0200769623             WAL-MAR  2020-03-31
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-21
# 46105          U001  0200769623           WAL-MAR in 2020-04-07
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1   48.0     0-15 days
# 46102                NAC6  1.930594e+09       1   48.0     0-15 days
# 46103                NAH4  1.930658e+09       1   -5.0     0-15 days
# 46104                NAH4  1.930620e+09       1   -9.0     0-15 days
# 46105                NAH4  1.930690e+09       1   -5.0     0-15 days
#
# [5 rows x 21 columns]

# %%
#prediction for clear_date
temp = temp_test_data['delay'].apply(np.ceil).apply(lambda x: pd.Timedelta(x, unit='D'))
temp_test_data['clear_date'] = temp_test_data['due_in_date'] + temp
# Out:
# <ipython-input-119-cc6340f03afa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['clear_date'] = temp_test_data['due_in_date'] + temp

# %%
# converted the delay into ceiling format
temp_test_data['delay'] = np.ceil(temp_test_data['delay'])
temp_test_data.head()
# Out:
# <ipython-input-120-224da961840e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay'] = np.ceil(temp_test_data['delay'])
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-06-11
# 46102          U001  0200762301    C&S WH associates 2020-05-06
# 46103          U001  0200769623             WAL-MAR  2020-03-28
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-14
# 46105          U001  0200769623           WAL-MAR in 2020-04-04
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1   48.0     0-15 days
# 46102                NAC6  1.930594e+09       1   48.0     0-15 days
# 46103                NAH4  1.930658e+09       1   -5.0     0-15 days
# 46104                NAH4  1.930620e+09       1   -9.0     0-15 days
# 46105                NAH4  1.930690e+09       1   -5.0     0-15 days
#
# [5 rows x 21 columns]

# %%
#buckting
l1 = temp_test_data['delay'].tolist() # pd series to list conversion
l2 = [] # empty list which will hold the bucket value
for x in l1:
    if x < 0:
        l2.append('0-15 days')
    elif x >= 0 and x <= 15:
        l2.append('0-15 days')
    elif x >= 16 and x <= 30:
        l2.append('16-30 days')
    elif x >=31 and x <= 45:
        l2.append('31-45 days')
    elif x >=46 and x <= 60:
        l2.append('46-60 days')
    else:
        l2.append('> 60 days')

# %%
temp_test_data['delay_bucket'] = l2
temp_test_data.head()
# Out:
# <ipython-input-122-a5c2dad2e7bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay_bucket'] = l2
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-06-11
# 46102          U001  0200762301    C&S WH associates 2020-05-06
# 46103          U001  0200769623             WAL-MAR  2020-03-28
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-14
# 46105          U001  0200769623           WAL-MAR in 2020-04-04
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1   48.0    46-60 days
# 46102                NAC6  1.930594e+09       1   48.0    46-60 days
# 46103                NAH4  1.930658e+09       1   -5.0     0-15 days
# 46104                NAH4  1.930620e+09       1   -9.0     0-15 days
# 46105                NAH4  1.930690e+09       1   -5.0     0-15 days
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Random Forest Regressor

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
# checking model in train_final
model_4 = RandomForestRegressor()
model_4.fit(X_train_scaled,y_train)
pred_value = model_4.predict(X_test_scaled)
print(f'score = {model_4.score(X_test_scaled,y_test)}')
print(f'r2_score = {r2_score(y_test,pred_value)}')
print(f'mean_squared_error = {mean_squared_error(y_test, pred_value)}')
root_mean_square_error=sqrt(mean_squared_error(y_test, pred_value))
print(f'root_mean_square_error = {root_mean_square_error}')
# Out:
# score = 0.218390866617455
# r2_score = 0.218390866617455
# mean_squared_error = 95.92156010513565
# root_mean_square_error = 9.793955284007358

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_validation_final_test_scaled = scaler.fit_transform(X_validation_final_test)

# %%
# checking model in validation_final
pred_value_validation = model_4.predict(X_validation_final_test_scaled)
print(f'score = {model_4.score(X_validation_final_test_scaled,y_validation_final_test)}')
print(f'r2_score = {r2_score(y_validation_final_test,pred_value_validation)}')
print(f'mean_squared_error = {mean_squared_error(y_validation_final_test, pred_value_validation)}')
root_mean_square_error_validation=sqrt(mean_squared_error(y_validation_final_test, pred_value_validation))
print(f'root_mean_square_error = {root_mean_square_error_validation}')
# Out:
# score = -1.1735210305858867
# r2_score = -1.1735210305858867
# mean_squared_error = 134.067081642478
# root_mean_square_error = 11.578734025897564

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
X_test_final_scaled = scaler.fit_transform(X_test_final_test)

# %%
# checking model in test_final
pred_value_test_final = model_4.predict(X_test_final_scaled)
print(f'score = {model_4.score(X_test_final_scaled,y_test_final_test)}')
print(f'r2_score = {r2_score(y_test_final_test,pred_value_test_final)}')
print(f'mean_squared_error = {mean_squared_error(y_test_final_test, pred_value_test_final)}')
root_mean_square_error_test_final=sqrt(mean_squared_error(y_test_final_test, pred_value_test_final))
print(f'root_mean_square_error = {root_mean_square_error_test_final}')
# Out:
# score = -3.878859723050268
# r2_score = -3.878859723050268
# mean_squared_error = 545.8321039832626
# root_mean_square_error = 23.363049971766586

# %%
#Normalization is performed before fitting inside model
scaler = StandardScaler()
test_scaled = scaler.fit_transform(test)

# %%
# checking model in test for prediction
pred_value_test = model_4.predict(test_scaled)
pred_value_test
# Out:
# array([16.99, 16.47, -6.45, ..., -7.43, 79.93,  2.32])

# %%
# delay is added to raw test data
temp_test_data['delay'] = pred_value_test
temp_test_data.head()
# Out:
# <ipython-input-131-843f9afe623a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay'] = pred_value_test
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-06-11
# 46102          U001  0200762301    C&S WH associates 2020-05-06
# 46103          U001  0200769623             WAL-MAR  2020-03-28
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-14
# 46105          U001  0200769623           WAL-MAR in 2020-04-04
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1  16.99    46-60 days
# 46102                NAC6  1.930594e+09       1  16.47    46-60 days
# 46103                NAH4  1.930658e+09       1  -6.45     0-15 days
# 46104                NAH4  1.930620e+09       1  -8.84     0-15 days
# 46105                NAH4  1.930690e+09       1   0.13     0-15 days
#
# [5 rows x 21 columns]

# %%
#now clear_date,due_in_date are converted to datetime format for predicting the clear_date
temp_test_data['clear_date'] = pd.to_datetime(temp_test_data['clear_date'])
temp_test_data['due_in_date'] = pd.to_datetime(temp_test_data['due_in_date'], format='%Y%m%d')
temp_test_data.head()
# Out:
# <ipython-input-132-eaf763d173fd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['clear_date'] = pd.to_datetime(temp_test_data['clear_date'])
# <ipython-input-132-eaf763d173fd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['due_in_date'] = pd.to_datetime(temp_test_data['due_in_date'], format='%Y%m%d')
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-06-11
# 46102          U001  0200762301    C&S WH associates 2020-05-06
# 46103          U001  0200769623             WAL-MAR  2020-03-28
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-14
# 46105          U001  0200769623           WAL-MAR in 2020-04-04
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1  16.99    46-60 days
# 46102                NAC6  1.930594e+09       1  16.47    46-60 days
# 46103                NAH4  1.930658e+09       1  -6.45     0-15 days
# 46104                NAH4  1.930620e+09       1  -8.84     0-15 days
# 46105                NAH4  1.930690e+09       1   0.13     0-15 days
#
# [5 rows x 21 columns]

# %%
#prediction for clear_date
temp = temp_test_data['delay'].apply(np.ceil).apply(lambda x: pd.Timedelta(x, unit='D'))
temp_test_data['clear_date'] = temp_test_data['due_in_date'] + temp
# Out:
# <ipython-input-133-cc6340f03afa>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['clear_date'] = temp_test_data['due_in_date'] + temp

# %%
# converted the delay into ceiling format
temp_test_data['delay'] = np.ceil(temp_test_data['delay'])
temp_test_data.head()
# Out:
# <ipython-input-134-224da961840e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay'] = np.ceil(temp_test_data['delay'])
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-05-11
# 46102          U001  0200762301    C&S WH associates 2020-04-05
# 46103          U001  0200769623             WAL-MAR  2020-03-27
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-15
# 46105          U001  0200769623           WAL-MAR in 2020-04-10
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1   17.0    46-60 days
# 46102                NAC6  1.930594e+09       1   17.0    46-60 days
# 46103                NAH4  1.930658e+09       1   -6.0     0-15 days
# 46104                NAH4  1.930620e+09       1   -8.0     0-15 days
# 46105                NAH4  1.930690e+09       1    1.0     0-15 days
#
# [5 rows x 21 columns]

# %%
#buckting
l1 = temp_test_data['delay'].tolist() # pd series to list conversion
l2 = [] # empty list which will hold the bucket value
for x in l1:
    if x < 0:
        l2.append('0-15 days')
    elif x >= 0 and x <= 15:
        l2.append('0-15 days')
    elif x >= 16 and x <= 30:
        l2.append('16-30 days')
    elif x >=31 and x <= 45:
        l2.append('31-45 days')
    elif x >=46 and x <= 60:
        l2.append('46-60 days')
    else:
        l2.append('> 60 days')

# %%
temp_test_data['delay_bucket'] = l2
temp_test_data.head()
# Out:
# <ipython-input-136-a5c2dad2e7bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp_test_data['delay_bucket'] = l2
#       business_code cust_number        name_customer clear_date  \
# 46101          U001  0200762301            C&S WH co 2020-05-11
# 46102          U001  0200762301    C&S WH associates 2020-04-05
# 46103          U001  0200769623             WAL-MAR  2020-03-27
# 46104          U001  0200769623  WAL-MAR corporation 2020-03-15
# 46105          U001  0200769623           WAL-MAR in 2020-04-10
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 46101         2020.0  1.930760e+09   2020-04-09              20200408
# 46102         2020.0  1.930594e+09   2020-03-04              20200303
# 46103         2020.0  1.930658e+09   2020-03-18              20200317
# 46104         2020.0  1.930620e+09   2020-03-08              20200307
# 46105         2020.0  1.930690e+09   2020-03-25              20200323
#
#        document_create_date.1 due_in_date  ... document type posting_id  \
# 46101                20200409  2020-04-24  ...            RV        1.0
# 46102                20200304  2020-03-19  ...            RV        1.0
# 46103                20200318  2020-04-02  ...            RV        1.0
# 46104                20200308  2020-03-23  ...            RV        1.0
# 46105                20200325  2020-04-09  ...            RV        1.0
#
#        area_business  total_open_amount  baseline_create_date  \
# 46101            NaN           21254.12            20200409.0
# 46102            NaN           48510.63            20200304.0
# 46103            NaN           15451.48            20200318.0
# 46104            NaN           33731.82            20200308.0
# 46105            NaN            1898.20            20200325.0
#
#        cust_payment_terms    invoice_id  isOpen  delay  delay_bucket
# 46101                NAC6  1.930760e+09       1   17.0    16-30 days
# 46102                NAC6  1.930594e+09       1   17.0    16-30 days
# 46103                NAH4  1.930658e+09       1   -6.0     0-15 days
# 46104                NAH4  1.930620e+09       1   -8.0     0-15 days
# 46105                NAH4  1.930690e+09       1    1.0     0-15 days
#
# [5 rows x 21 columns]

# %%
temp_test_data.describe()
# Out:
#        buisness_year        doc_id  document_create_date  \
# count         3899.0  3.899000e+03          3.899000e+03
# mean          2020.0  2.000820e+09          2.020037e+07
# std              0.0  2.582422e+08          7.000721e+01
# min           2020.0  1.930535e+09          2.020022e+07
# 25%           2020.0  1.930660e+09          2.020032e+07
# 50%           2020.0  1.930732e+09          2.020033e+07
# 75%           2020.0  1.930819e+09          2.020042e+07
# max           2020.0  2.960635e+09          2.020052e+07
#
#        document_create_date.1  posting_id  area_business  total_open_amount  \
# count            3.899000e+03      3899.0            0.0        3899.000000
# mean             2.020037e+07         1.0            NaN       32924.807833
# std              6.948637e+01         0.0            NaN       36276.267032
# min              2.020023e+07         1.0            NaN           5.810000
# 25%              2.020032e+07         1.0            NaN        5495.415000
# 50%              2.020033e+07         1.0            NaN       19145.650000
# 75%              2.020042e+07         1.0            NaN       49259.525000
# max              2.020052e+07         1.0            NaN      292561.560000
#
#        baseline_create_date    invoice_id  isOpen        delay
# count          3.899000e+03  3.899000e+03  3899.0  3899.000000
# mean           2.020037e+07  2.000820e+09     1.0     6.631957
# std            6.931527e+01  2.582422e+08     0.0    23.048652
# min            2.020023e+07  1.930535e+09     1.0   -27.000000
# 25%            2.020032e+07  1.930660e+09     1.0    -5.000000
# 50%            2.020033e+07  1.930732e+09     1.0     0.000000
# 75%            2.020042e+07  1.930819e+09     1.0     4.000000
# max            2.020052e+07  2.960635e+09     1.0    86.000000
