# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('H2HBABBA1533.csv')

# %%
data.head()
# Out:
#   business_code cust_number    name_customer           clear_date  \
# 0          U001  0200769623     WAL-MAR corp  2019-12-27 00:00:00
# 1          U001  0200777735           NASH    2019-02-25 00:00:00
# 2          U001      CCU013         KRAFT F   2019-08-02 00:00:00
# 3          U001  0200793000  US  corporation  2019-05-17 00:00:00
# 4          U001  0200769623       WAL-MAR co  2019-12-24 00:00:00
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2019.0  1.930283e+09   2019-12-15              20191215
# 1         2019.0  1.928774e+09   2019-02-11              20190209
# 2         2019.0  1.929514e+09   2019-06-21              20190619
# 3         2019.0  1.929240e+09   2019-05-02              20190501
# 4         2019.0  1.930269e+09   2019-12-14              20191212
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20191215   20191230.0              USD            RV
# ...

# %%
data['business_code'].value_counts()
# Out:
# U001    45275
# CA02     3902
# U013      647
# U002      157
# U005       18
# U007        1
# Name: business_code, dtype: int64
