# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold

# %%
data = pd.read_csv('H2HBABBA1533.csv')

# %%
data.head()
# Out:
#   business_code cust_number       name_customer           clear_date  \
# 0          U001  0200895843                US    2019-09-09 00:00:00
# 1          U001  0200769623            WAL-MAR   2019-11-25 00:00:00
# 2          U001  0200769623  WAL-MAR foundation  2019-04-23 00:00:00
# 3          U001  0200769623          WAL-MAR co  2019-11-26 00:00:00
# 4          U001  0200769623            WAL-MAR                   NaN
#
#    buisness_year        doc_id posting_date  document_create_date  \
# 0         2019.0  1.929776e+09   2019-08-22              20190822
# 1         2019.0  1.930144e+09   2019-11-12              20191112
# 2         2019.0  1.929131e+09   2019-04-12              20190411
# 3         2019.0  1.930124e+09   2019-11-15              20191107
# 4         2020.0  1.930737e+09   2020-04-03              20200403
#
#    document_create_date.1  due_in_date invoice_currency document type  \
# 0                20190822   20190906.0              USD            RV
# ...

# %%
data['business_code'].value_counts()
# Out:
# U001    45451
# CA02     3813
# U013      559
# U002      162
# U005       12
# U007        3
# Name: business_code, dtype: int64

# %%
# separate dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(
    data.drop(labels=['isOpen'], axis=1),
    data['isOpen'],
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((35000, 18), (15000, 18))

# %%
X_train.isnull().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                 7053
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             35000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    3
# dtype: int64

# %%
#since area of business has all the null -values so drop the column
X_train.drop(columns=['area_business','invoice_id'],inplace=True)

# %%
X_train.isnull().sum()
# Out:
# business_code                0
# cust_number                  0
# name_customer                0
# clear_date                7053
# buisness_year                0
# doc_id                       0
# posting_date                 0
# document_create_date         0
# document_create_date.1       0
# due_in_date                  0
# invoice_currency             0
# document type                0
# posting_id                   0
# total_open_amount            0
# baseline_create_date         0
# cust_payment_terms           0
# dtype: int64

# %%
X_train.duplicated().sum()
# Out:
# 625

# %%
data_t = X_train.T
data_t.head()
# Out:
#                              17967                32391       9341   \
# business_code                 U001                 U001        U001
# cust_number             0200769623           0200769623  0200803720
# name_customer         WAL-MAR corp           WAL-MAR co   DEC trust
# clear_date     2020-01-27 00:00:00  2019-04-25 00:00:00         NaN
# buisness_year               2020.0               2019.0      2020.0
#
#                      7929                 46544                4149   \
# business_code         U001                 U001                 U001
# cust_number     0200769623           0200744019               CCCA02
# name_customer  WAL-MAR llc              TARG in           KRAFT  llc
# clear_date             NaN  2020-02-11 00:00:00  2019-01-17 00:00:00
# buisness_year       2020.0               2020.0               2019.0
#
#                              33426                3002                 6974   \
# ...

# %%
data_t.duplicated().sum()
# Out:
# 0

# %%
#check if there exist a consta features or not
X_train.columns[X_train.nunique()<=1]
# Out:
# Index(['posting_id'], dtype='object')

# %%
X_train.drop('posting_id',axis =1,inplace =True)

# %%
X_train.shape
# Out:
# (35000, 15)

# %%
# changing the object to data-Time datatype
X_train['posting_date'] = pd.to_datetime(X_train['posting_date']) 
X_train['due_in_date'] = pd.to_datetime(X_train['due_in_date'], format='%Y%m%d')
X_train['document_create_date.1'] = pd.to_datetime(X_train['document_create_date.1'], format='%Y%m%d')
X_train['document_create_date'] = pd.to_datetime(X_train['document_create_date.1'], format='%Y%m%d')
X_train.head()
# Out:
#       business_code cust_number name_customer  buisness_year        doc_id  \
# 17967          U001  0200769623  WAL-MAR corp         2020.0  1.930401e+09
# 32391          U001  0200769623    WAL-MAR co         2019.0  1.929141e+09
# 9341           U001  0200803720     DEC trust         2020.0  1.930690e+09
# 7929           U001  0200769623   WAL-MAR llc         2020.0  1.930690e+09
# 46544          U001  0200744019       TARG in         2020.0  1.930441e+09
#
#       posting_date document_create_date document_create_date.1 due_in_date  \
# 17967   2020-01-15           2020-01-15             2020-01-15  2020-01-30
# 32391   2019-04-14           2019-04-14             2019-04-14  2019-04-29
# 9341    2020-03-24           2020-03-24             2020-03-24  2020-04-08
# 7929    2020-03-23           2020-03-23             2020-03-23  2020-04-07
# 46544   2020-01-26           2020-01-26             2020-01-26  2020-02-10
#
# ...
